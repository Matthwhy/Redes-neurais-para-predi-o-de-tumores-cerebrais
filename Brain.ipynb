# %%
import os
from PIL import Image
import numpy as np 
import pandas as pd

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]])
# Out:
# OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='error', sparse=True)

# %%
OneHotEncoder()
# Out:
# OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='error', sparse=True)

# %%
data = []
paths = []
result = []

for r, d, f in os.walk(r'/content/drive/MyDrive/Colab Notebooks/Projetos/brain/brain_tumor_dataset/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())
result[0]
# Out:
# array([[1., 0.]])

# %%
paths = []
for r, d, f in os.walk(r"/content/drive/MyDrive/Colab Notebooks/Projetos/brain/brain_tumor_dataset/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)
result.shape
# Out:
# (139, 2)

# %%
train_images, test_images, train_labels, test_labels = train_test_split(data, result, test_size=0.1, shuffle=True, random_state=1)

# %%
print('Train Images Shape', train_images.shape)
print('Train Labels Shape', train_labels.shape)
print('Test Images Shape', test_images.shape)
print('Test Labels Shape', test_labels.shape)
# Out:
# Train Images Shape (125, 128, 128, 3)
# Train Labels Shape (125, 2)
# Test Images Shape (14, 128, 128, 3)
# Test Labels Shape (14, 2)

# %%
inputs = tf.keras.Input(shape=(128, 128, 3))

conv2d_layer = tf.keras.layers.Conv2D(32, (2,2), padding='Same')(inputs)
conv2d_layer = tf.keras.layers.Conv2D(32, (2,2), activation='relu', padding='Same')(conv2d_layer)

bn_layer = tf.keras.layers.BatchNormalization()(conv2d_layer)
mp_layer = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(bn_layer)
drop = tf.keras.layers.Dropout(0.25)(mp_layer)

conv2d_layer = tf.keras.layers.Conv2D(64, (2,2), activation='relu', padding='Same')(drop)
conv2d_layer = tf.keras.layers.Conv2D(64, (2,2), activation='relu', padding='Same')(conv2d_layer)

bn_layer = tf.keras.layers.BatchNormalization()(conv2d_layer)
mp_layer = tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2))(bn_layer)
drop = tf.keras.layers.Dropout(0.25)(mp_layer)

flatten_layer = tf.keras.layers.Flatten()(drop)

dense_layer = tf.keras.layers.Dense(512, activation='relu')(flatten_layer)
drop = tf.keras.layers.Dropout(0.5)(dense_layer)
outputs = tf.keras.layers.Dense(2, activation='softmax')(drop)

model = tf.keras.Model(inputs=inputs, outputs=outputs, name='tumor_model')
model.summary()
# Out:
# Model: "tumor_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 32)      416
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        8256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        16448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33554944
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 33,585,602
# Trainable params: 33,585,410
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(loss = tf.keras.losses.CategoricalCrossentropy(),
             optimizer = tf.keras.optimizers.Adamax(),
             metrics = ['accuracy'])

# %%
history = model.fit(train_images, train_labels,
                   epochs=40,
                   batch_size=128,
                   validation_data=(test_images, test_labels))
# Out:
# Epoch 1/40
# 1/1 [==============================] - 10s 10s/step - loss: 2.1242 - accuracy: 0.4160 - val_loss: 70.7845 - val_accuracy: 0.5000
# Epoch 2/40
# 1/1 [==============================] - 8s 8s/step - loss: 24.1295 - accuracy: 0.7200 - val_loss: 31.8547 - val_accuracy: 0.5714
# Epoch 3/40
# 1/1 [==============================] - 8s 8s/step - loss: 9.9434 - accuracy: 0.7280 - val_loss: 40.4267 - val_accuracy: 0.6429
# Epoch 4/40
# 1/1 [==============================] - 8s 8s/step - loss: 3.3627 - accuracy: 0.8320 - val_loss: 36.9470 - val_accuracy: 0.6429
# Epoch 5/40
# 1/1 [==============================] - 8s 8s/step - loss: 3.3743 - accuracy: 0.8560 - val_loss: 34.1162 - val_accuracy: 0.6429
# Epoch 6/40
# 1/1 [==============================] - 8s 8s/step - loss: 2.5581 - accuracy: 0.7840 - val_loss: 39.5597 - val_accuracy: 0.6429
# Epoch 7/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.8541 - accuracy: 0.9120 - val_loss: 43.7307 - val_accuracy: 0.6429
# Epoch 8/40
# 1/1 [==============================] - 7s 7s/step - loss: 1.3436 - accuracy: 0.9280 - val_loss: 41.5328 - val_accuracy: 0.6429
# Epoch 9/40
# 1/1 [==============================] - 7s 7s/step - loss: 1.2474 - accuracy: 0.9200 - val_loss: 36.7279 - val_accuracy: 0.6429
# Epoch 10/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.8104 - accuracy: 0.9440 - val_loss: 29.7789 - val_accuracy: 0.6429
# Epoch 11/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.6231 - accuracy: 0.9600 - val_loss: 23.2662 - val_accuracy: 0.6429
# Epoch 12/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.9589 - accuracy: 0.9280 - val_loss: 18.5314 - val_accuracy: 0.6429
# Epoch 13/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.0191 - accuracy: 0.9920 - val_loss: 15.4626 - val_accuracy: 0.7143
# Epoch 14/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.0342 - accuracy: 0.9840 - val_loss: 13.0522 - val_accuracy: 0.7143
# Epoch 15/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.0446 - accuracy: 0.9920 - val_loss: 11.0229 - val_accuracy: 0.7143
# Epoch 16/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.2371 - accuracy: 0.9760 - val_loss: 9.1949 - val_accuracy: 0.7143
# Epoch 17/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.2870 - accuracy: 0.9840 - val_loss: 7.9016 - val_accuracy: 0.7143
# Epoch 18/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.0257 - accuracy: 0.9920 - val_loss: 6.9877 - val_accuracy: 0.7143
# Epoch 19/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.4609 - accuracy: 0.9600 - val_loss: 5.4800 - val_accuracy: 0.7857
# Epoch 20/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0552 - accuracy: 0.9840 - val_loss: 4.5723 - val_accuracy: 0.6429
# Epoch 21/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.0295 - accuracy: 0.9920 - val_loss: 3.9161 - val_accuracy: 0.6429
# Epoch 22/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.1187 - accuracy: 0.9920 - val_loss: 3.6749 - val_accuracy: 0.7143
# Epoch 23/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0547 - accuracy: 0.9760 - val_loss: 3.5032 - val_accuracy: 0.7857
# Epoch 24/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0914 - accuracy: 0.9760 - val_loss: 3.3276 - val_accuracy: 0.7857
# Epoch 25/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0546 - accuracy: 0.9920 - val_loss: 3.1642 - val_accuracy: 0.7857
# Epoch 26/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0251 - accuracy: 0.9920 - val_loss: 3.0952 - val_accuracy: 0.6429
# Epoch 27/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0469 - accuracy: 0.9920 - val_loss: 3.2672 - val_accuracy: 0.7857
# Epoch 28/40
# 1/1 [==============================] - 8s 8s/step - loss: 3.5178e-05 - accuracy: 1.0000 - val_loss: 3.5794 - val_accuracy: 0.7143
# Epoch 29/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0162 - accuracy: 0.9920 - val_loss: 3.7787 - val_accuracy: 0.7143
# Epoch 30/40
# 1/1 [==============================] - 7s 7s/step - loss: 3.0088e-04 - accuracy: 1.0000 - val_loss: 3.9447 - val_accuracy: 0.7143
# Epoch 31/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 4.3044 - val_accuracy: 0.7143
# Epoch 32/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0075 - accuracy: 0.9920 - val_loss: 4.4662 - val_accuracy: 0.7143
# Epoch 33/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0584 - accuracy: 0.9840 - val_loss: 4.6202 - val_accuracy: 0.7143
# Epoch 34/40
# 1/1 [==============================] - 8s 8s/step - loss: 0.0306 - accuracy: 0.9920 - val_loss: 5.3590 - val_accuracy: 0.7143
# Epoch 35/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 5.9782 - val_accuracy: 0.7143
# Epoch 36/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.3235 - accuracy: 0.9760 - val_loss: 5.7303 - val_accuracy: 0.7143
# Epoch 37/40
# 1/1 [==============================] - 7s 7s/step - loss: 1.7427e-05 - accuracy: 1.0000 - val_loss: 5.4753 - val_accuracy: 0.7143
# Epoch 38/40
# 1/1 [==============================] - 7s 7s/step - loss: 2.4659e-06 - accuracy: 1.0000 - val_loss: 5.2368 - val_accuracy: 0.7143
# Epoch 39/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.0457 - accuracy: 0.9920 - val_loss: 5.2119 - val_accuracy: 0.7143
# Epoch 40/40
# 1/1 [==============================] - 7s 7s/step - loss: 0.0657 - accuracy: 0.9920 - val_loss: 4.7187 - val_accuracy: 0.7143

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()
ac = 99

# %%
def names(number):
    if number==0:
        return 'é um tumor'
    else:
        return 'não é um tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"/content/drive/MyDrive/Colab Notebooks/Projetos/brain/brain_tumor_dataset/no/21 no.jpg")
x = np.array(img.resize((128,128)))
ac = 99
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*ac) + '%  De Confiança, isto ' + names(classification))
# Out:
# 88.4184188246727%  De Confiança, isto não é um tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"/content/drive/MyDrive/Colab Notebooks/Projetos/brain/brain_tumor_dataset/yes/Y34.jpg")
x = np.array(img.resize((128,128)))

x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*98) + '%  De Confiança, isto ' + names(classification))
# Out:
# 98.0%  De Confiança, isto é um tumor
